# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h2>Objective</h2><ul><li> How to download and pre-process the Concrete dataset.</li></ul> <p>Crack detection has vital importance for structural health monitoring and inspection. We would like to train a network to detect Cracks, we will denote the images that contain cracks as positive and images with no cracks as negative. In this lab you are going to have to download the data and study the dataset. There are two questions in this lab, including listing the path to some of the image files as well as plotting a few images. Remember the results as you will be quizzed on them. </p>

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#download_data"> Download data</a></li>
#     <li><a href="#examine_files">Examine Files</a></li>
#     <li><a href="#Question_1">Question 1 </a></li>
#     <li><a href="#Display">Display and Analyze Image With No Cracks    </a></li>
#     <li><a href="#Question_2">Question 2 </a></li>
# </ul>
# <p>Estimated Time Needed: <strong>25 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab:

# %%
# %pip install skillsnetwork
# Out:
# Requirement already satisfied: skillsnetwork in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (0.21.9)
# Requirement already satisfied: ipython in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from skillsnetwork) (8.27.0)
# Requirement already satisfied: ipywidgets<9,>=8 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from skillsnetwork) (8.1.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from skillsnetwork) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from skillsnetwork) (4.67.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (3.0.13)
# Requirement already satisfied: decorator in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: exceptiongroup in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (4.11.0)
# Requirement already satisfied: colorama in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from ipython->skillsnetwork) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from requests<3,>=2->skillsnetwork) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from requests<3,>=2->skillsnetwork) (2024.8.30)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->skillsnetwork) (0.2.5)
# Requirement already satisfied: executing in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from stack-data->ipython->skillsnetwork) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.2.2)
# Requirement already satisfied: six in c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages (from asttokens->stack-data->ipython->skillsnetwork) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\development\ibm deep learning with pytorch, keras and tensorflow\.conda\lib\site-packages)

# %%
from PIL import Image
from matplotlib.pyplot import imshow
import pandas
import matplotlib.pylab as plt
import os
import glob

# %% [markdown]
# We will use this function in the lab to plot:

# %%
def show_data(data_sample, shape = (28, 28)):
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.title('y = ' + data_sample[1])

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# In this section, you are going to download the data from IBM object storage using **skillsnetwork.prepare** command. <b>skillsnetwork.prepare</b> is a command that's used to download a zip file, unzip it and store it in a specified directory. Locally we store the data in the directory  **/resources/data**.

# %%
url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip"

# %%
# import skillsnetwork
# await skillsnetwork.prepare(url, path="/resources/data", overwrite=True)

# %%
# download the url with requests and save downloaded file to resources/data folder

import requests

from zipfile import ZipFile

import os

# Common path strings
data_dir = os.path.join("resources","data")
cwd = os.getcwd()
zip_file_path = os.path.join(data_dir, "concrete_crack_images_for_classification.zip")

print(data_dir)
print(cwd)
print(zip_file_path)

# Ensure the directory exists
os.makedirs(data_dir, exist_ok=True)

r = requests.get(url, stream=True)
with open(zip_file_path, "wb") as file:
    for block in r.iter_content(chunk_size=1024):
        if block:
            file.write(block)

# Unzip the file
with ZipFile(zip_file_path, "r") as zip_ref:
    zip_ref.extractall(data_dir)
# Out:
# resources\data
# c:\Users\admin\Development\IBM Deep Learning with PyTorch, Keras and Tensorflow\5. ai-capstone-project-with-deep-learning
# resources\data\concrete_crack_images_for_classification.zip

# %%
# remove the zip file
os.remove(zip_file_path)

# %% [markdown]
# We then download the files that contain the negative images:

# %% [markdown]
# <h2 id="examine_files">Examine Files </h2>

# %% [markdown]
# In this section we are going to get a list of the negative image files, then plot them. Then for the first question your job to do something similar to the positive files.

# %% [markdown]
# The path to all the images are stored in the variable  <code>directory</code>.

# %%
# directory="/resources/data"
directory = os.path.join("resources","data")

# %% [markdown]
# The images with out the cracks are stored in the file <b>Negative</b>

# %%
negative='Negative'

# %% [markdown]
# We can find the path to the file with all the negative images by  using the function <code>os.path.join</code>. Inputs are the variable directory as well as the variable  <code>negative</code>.

# %%
negative_file_path=os.path.join(directory,negative)
negative_file_path
# Out:
# 'resources\\data\\Negative'

# %% [markdown]
# <h3> Loading the File Path of Each Image </h3>

# %% [markdown]
# We need each the path of each image, we can find the all the file in the directory  <code>negative_file_path</code> using the function <code>os.listdir</code>, the result is a list. We print out the first three elements of the list.

# %%
 os.listdir(negative_file_path)[0:3]
# Out:
# ['00001.jpg', '00002.jpg', '00003.jpg']

# %% [markdown]
# We need the full path of the image so we join them as above. Here are a few samples  three samples:

# %%
[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path)][0:3]
# Out:
# ['resources\\data\\Negative\\00001.jpg',
#  'resources\\data\\Negative\\00002.jpg',
#  'resources\\data\\Negative\\00003.jpg']

# %% [markdown]
# In some cases, we may have files of a different type, so we have to ensure it's of type <b>jpg</b>. We have to check the extension using the method <code> endswith()</code>. The method  <code>endswith()</code> returns True if the string ends with the specified suffix, otherwise, it will return False. Let's do a quick example:

# %%
print("test.jpg".endswith(".jpg"))
print("test.mpg".endswith(".jpg"))
# Out:
# True
# False

# %% [markdown]
# We now have all the tools to create a list with the path to each image file.  We use a List Comprehensions  to make the code more compact. We assign it to the variable <code>negative_files<code> , sort it in and display the first three elements:

# %%
negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
negative_files.sort()
negative_files[0:10]
# Out:
# ['resources\\data\\Negative\\00001.jpg',
#  'resources\\data\\Negative\\00002.jpg',
#  'resources\\data\\Negative\\00003.jpg',
#  'resources\\data\\Negative\\00004.jpg',
#  'resources\\data\\Negative\\00005.jpg',
#  'resources\\data\\Negative\\00006.jpg',
#  'resources\\data\\Negative\\00007.jpg',
#  'resources\\data\\Negative\\00008.jpg',
#  'resources\\data\\Negative\\00009.jpg',
#  'resources\\data\\Negative\\00010.jpg']

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Using the procedure above, load all the images with cracks paths into a list called positive files, the directory of these images is called Positive.  Make sure the list is sorted and display the first three elements of the list you will need this for the question so remember it.</b>

# %%
positive="Positive"

positive_file_path=os.path.join(directory,positive)
positive_files = [os.path.join(positive_file_path, file) for file in os.listdir(positive_file_path) if file.endswith(".jpg")]

positive_files.sort()
positive_files[0:3]
# Out:
# ['resources\\data\\Positive\\00001.jpg',
#  'resources\\data\\Positive\\00002.jpg',
#  'resources\\data\\Positive\\00003.jpg']

# %% [markdown]
# <h2 id="Display">Display and Analyze Image With No Cracks</h2>

# %% [markdown]
# We can open an image by using the <code>Image</code> Module in the  <b>PIL</b> library, using the function open. We only require the image path; the input is the path of the image. For example we can load the first image as follows:

# %%
image1 = Image.open(negative_files[0])
# you can view the image directly 
#image

# %% [markdown]
# we can plot the image

# %%
plt.imshow(image1)
plt.title("1st Image With No Cracks")
plt.show()

# %% [markdown]
# We can also plot the second image.

# %%
image2 = Image.open(negative_files[1])
plt.imshow(image2)
plt.title("2nd Image With No Cracks")
plt.show()

# %% [markdown]
# <h2 id="Question_2">Question 2</h2>

# %% [markdown]
# <b>Plot the first three images for the dataset with cracks. Don't forget. You will be asked in the quiz, so remember the image. </b>

# %%
plt.figure(figsize=(15, 5))

for i in range(3):
    image3 = Image.open(positive_files[i])
    plt.subplot(1, 3, i+1)
    plt.imshow(image3)
    plt.title(f"Image no. {i+1} With Cracks")
    plt.axis('off')

plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
#  [Alex Aklson](https://www.linkedin.com/in/aklson/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01). Ph.D., is a data scientist in the Digital Business Group at IBM Canada. Alex has been intensively involved in many exciting data science projects such as designing a smart system that could detect the onset of dementia in older adults using longitudinal trajectories of walking speed and home activity. Before joining IBM, Alex worked as a data scientist at Datascope Analytics, a data science consulting firm in Chicago, IL, where he designed solutions and products using a human-centred, data-driven approach. Alex received his Ph.D. in Biomedical Engineering from the University of Toronto.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-18  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
